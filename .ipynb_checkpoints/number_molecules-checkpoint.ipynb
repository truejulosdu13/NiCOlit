# %% [markdown]
# # Import tools

# %%
import numpy as np
import pandas as pd
from rdkit import Chem
from rdkit.Chem import Draw
from rdkit.Chem import AllChem
import fragmentation as fg
from rdkit import RDLogger
RDLogger.DisableLog('rdApp.*')

# %% [markdown]
# # Load data

# %%
df = pd.read_csv('Data_test09032021.csv', sep = ',')
df
# Out:
#        Index Reactant Smile (C-O)                               A-X  \
# 0        0.0     COc1ccc2ccccc2c1                      [Li]c1ccccc1
# 1        1.0     COc1ccc2ccccc2c1                      [Li]c1ccccc1
# 2        2.0     COc1ccc2ccccc2c1                      [Li]c1ccccc1
# 3        3.0     COc1ccc2ccccc2c1                      [Li]c1ccccc1
# 4        4.0     COc1ccc2ccccc2c1                      [Li]c1ccccc1
# ...      ...                  ...                               ...
# 1983  2103.0     COc2ccc1ccccc1c2  CC2(C)COB(c1ccc(C(F)(F)F)cc1)OC2
# 1984  2104.0     COc2ccc1ccccc1c2    Cc2ccc(B1OC(C)(C)C(C)(C)O1)cc2
# 1985  2105.0     COc2ccc1ccccc1c2    CC(=O)c2ccc(B1OCC(C)(C)CO1)cc2
# 1986  2106.0     COc2ccc1ccccc1c2     CN(C)c2ccc(B1OCC(C)(C)CO1)cc2
# 1987  2107.0     COc2ccc1ccccc1c2                CCCCB1OCC(C)(C)CO1
#
#                           A-X effectif  Solvent Time Temperature  \
# 0                         [Li]c1ccccc1  toluene  12h          rt
# 1                         [Li]c1ccccc1  toluene  12h          rt
# 2                         [Li]c1ccccc1  toluene  12h          rt
# 3                         [Li]c1ccccc1  toluene  12h          rt
# 4                         [Li]c1ccccc1  toluene  12h          rt
# ...                                ...      ...  ...         ...
# 1983  CC2(C)COB(c1ccc(C(F)(F)F)cc1)OC2  toluene   3h       120°C
# 1984    Cc2ccc(B1OC(C)(C)C(C)(C)O1)cc2  toluene   3h       120°C
# 1985    CC(=O)c2ccc(B1OCC(C)(C)CO1)cc2  toluene   3h       120°C
# 1986     CN(C)c2ccc(B1OCC(C)(C)CO1)cc2  toluene   3h       120°C
# 1987                CCCCB1OCC(C)(C)CO1  toluene   3h       120°C
#
#      Precurseur Nickel                      Base/additifs  \
# 0             Ni(cod)2                                NaN
# 1             Ni(cod)2                                NaN
# 2             Ni(cod)2                                NaN
# 3             Ni(cod)2                                NaN
# 4             Ni(cod)2                                NaN
# ...                ...                                ...
# 1983          Ni(cod)2  CC(C)(C)O[Al](OC(C)(C)C)OC(C)(C)C
# 1984          Ni(cod)2  CC(C)(C)O[Al](OC(C)(C)C)OC(C)(C)C
# 1985          Ni(cod)2  CC(C)(C)O[Al](OC(C)(C)C)OC(C)(C)C
# 1986          Ni(cod)2  CC(C)(C)O[Al](OC(C)(C)C)OC(C)(C)C
# 1987          Ni(cod)2  CC(C)(C)O[Al](OC(C)(C)C)OC(C)(C)C
#
#      Base/additif après correction effective  ...  \
# 0                                        NaN  ...
# 1                                        NaN  ...
# 2                                        NaN  ...
# 3                                        NaN  ...
# 4                                        NaN  ...
# ...                                      ...  ...
# 1983       CC(C)(C)O[Al](OC(C)(C)C)OC(C)(C)C  ...
# 1984       CC(C)(C)O[Al](OC(C)(C)C)OC(C)(C)C  ...
# 1985       CC(C)(C)O[Al](OC(C)(C)C)OC(C)(C)C  ...
# 1986       CC(C)(C)O[Al](OC(C)(C)C)OC(C)(C)C  ...
# 1987       cC(C)(C)O[Al](OC(C)(C)C)OC(C)(C)C  ...
#
#                     Ligand effectif                           Product  \
# 0                               NaN          c3ccc(c2ccc1ccccc1c2)cc3
# 1                              PCy3          c3ccc(c2ccc1ccccc1c2)cc3
# 2                              dppe          c3ccc(c2ccc1ccccc1c2)cc3
# 3                              ItBu          c3ccc(c2ccc1ccccc1c2)cc3
# 4                               ICy          c3ccc(c2ccc1ccccc1c2)cc3
# ...                             ...                               ...
# 1983  C3CCC(P(C1CCCCC1)C2CCCCC2)CC3  FC(F)(F)c3cccc(c2ccc1ccccc1c2)c3
# 1984  C3CCC(P(C1CCCCC1)C2CCCCC2)CC3         Cc3ccc(c2ccc1ccccc1c2)cc3
# 1985  C3CCC(P(C1CCCCC1)C2CCCCC2)CC3    CC(=O)c3ccc(c2ccc1ccccc1c2)cc3
# 1986  C3CCC(P(C1CCCCC1)C2CCCCC2)CC3     CN(C)c3ccc(c2ccc1ccccc1c2)cc3
# 1987  C3CCC(P(C1CCCCC1)C2CCCCC2)CC3      CCCCc3ccc(c2ccc1ccccc1c2)cc3
#
#      GC/NMR Yield Isolated Yield                                     DOI  \
# 0              73            NaN  https://doi.org/10.1002/chem.201603436
# 1              62            NaN  https://doi.org/10.1002/chem.201603436
# 2               0            NaN  https://doi.org/10.1002/chem.201603436
# 3              76            NaN  https://doi.org/10.1002/chem.201603436
# 4              66            NaN  https://doi.org/10.1002/chem.201603436
# ...           ...            ...                                     ...
# 1983           84            NaN                                   Thèse
# 1984          100            NaN                                   Thèse
# 1985            0            NaN                                   Thèse
# 1986            0            NaN                                   Thèse
# 1987            0            NaN                                   Thèse
#
#      type of data (optimisation table or scope)  \
# 0                            Optimisation table
# 1                            Optimisation table
# 2                            Optimisation table
# 3                            Optimisation table
# 4                            Optimisation table
# ...                                         ...
# 1983                       Table d'optimisation
# 1984                       Table d'optimisation
# 1985                       Table d'optimisation
# 1986                       Table d'optimisation
# 1987                       Table d'optimisation
#
#      Notes : qu'est ce qui ne rentres pas dans le tableau  \
# 0                                               Table 1
# 1                                               Table 1
# 2                                               Table 1
# 3                                               Table 1
# 4                                               Table 1
# ...                                                 ...
# 1983                               page 129 - Scheme 58
# 1984                               page 129 - Scheme 58
# 1985                               page 129 - Scheme 58
# 1986                               page 129 - Scheme 58
# 1987                               page 129 - Scheme 58
#
#                               Notes bis : modifications Unnamed: 19  \
# 0     en jaune les ligands protonés sont déprotonés ...         NaN
# 1     en jaune les ligands protonés sont déprotonés ...         NaN
# 2     en jaune les ligands protonés sont déprotonés ...         NaN
# 3     en jaune les ligands protonés sont déprotonés ...         NaN
# 4     en jaune les ligands protonés sont déprotonés ...         NaN
# ...                                                 ...         ...
# 1983                                                NaN         NaN
# 1984                                                NaN         NaN
# 1985                                                NaN         NaN
# 1986                                                NaN         NaN
# 1987                                                NaN         NaN
#
#      Unnamed: 20
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 1983         NaN
# 1984         NaN
# 1985         NaN
# 1986         NaN
# 1987         NaN
#
# [1988 rows x 21 columns]

# %% [markdown]
# # Check if data is clean

# %%
for i in df["Product"]:
    m = Chem.MolFromSmiles(i,sanitize=False)
    if m is None:
          print('invalid', i)

# %% [markdown]
# # Generate fragments for the substrate on the C-O involved in the coupling

# %%
df["Reactant Smile (C-O)"]
# Out:
# 0       COc1ccc2ccccc2c1
# 1       COc1ccc2ccccc2c1
# 2       COc1ccc2ccccc2c1
# 3       COc1ccc2ccccc2c1
# 4       COc1ccc2ccccc2c1
#               ...
# 1983    COc2ccc1ccccc1c2
# 1984    COc2ccc1ccccc1c2
# 1985    COc2ccc1ccccc1c2
# 1986    COc2ccc1ccccc1c2
# 1987    COc2ccc1ccccc1c2
# Name: Reactant Smile (C-O), Length: 1988, dtype: object

# %%
mol_frags = fg.gen_fragments_on_CO_break(df["Reactant Smile (C-O)"], df["Product"])

# %%
unik_mol_frags = fg.unique_elements(mol_frags)

# %%
OC_unik = []
OC_prod = []
for i, j  in enumerate(df["Reactant Smile (C-O)"]):
    smi = Chem.MolToSmiles(Chem.MolFromSmiles(j))
    if smi not in OC_unik:
        OC_unik.append(smi)
        OC_prod.append(df["Product"][i])
        
fragC = []
fragO = []
for i in range(len(OC_unik)):
    smi = OC_unik[i]
    frag = fg.gen_frag_on_CO_break(OC_unik[i], OC_prod[i])
    if len(frag) > 1:
        fragC.append(frag[0])
        fragO.append(frag[1])
    elif len(frag) == 1:
        fragC.append(frag[0])
        fragO.append('nan')

# %%
df2 = pd.DataFrame(data={"react": OC_unik, "fragC": fragC, "fragO": fragO, "product": OC_prod})
df2.to_csv("./fragments.csv", sep=',',index=False)
